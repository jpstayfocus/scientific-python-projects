# %%
a = 4
b = 3
c = 7
print( a )
print( b )
# Out:
# 4
# 3

# %%
print(c)
# Out:
# 7

# %%
d = 'Hello, '
e = "Jephte's favorite color is purple"
print(d, e)
# Out:
# Hello,  Jephte's favorite color is purple

# %%
# this is a comment
filter_Order = 2048
data2plot = 3

# %%
# multiple assignments
f, g = 10, 20
print(f, g)
# Out:
# 10 20

# %%
# %whos
# Out:
# Variable       Type    Data/Info
# --------------------------------
# a              int     4
# b              int     3
# c              int     7
# d              str     Hello,
# data2plot      int     3
# e              str     Jephte's favorite color is purple
# f              int     10
# filter_Order   int     2048
# g              int     20
