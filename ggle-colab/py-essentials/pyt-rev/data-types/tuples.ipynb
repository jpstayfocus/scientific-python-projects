# %%
# Tuples

atuple = (3, '4', 3)
atuple
atuple * 3
atuple.count(3)

# tuples are immutable and
# lists are mutable

aList = [3, '4', 3]
atuple = (3, '4', 3)

print(aList)
print(atuple)

aList[0] = 5
#atuple[0] = 5, error
atyple = (5, '4', 3)


print(aList)
print(atuple)
# Out:
# [3, '4', 3]
# (3, '4', 3)
# [5, '4', 3]
# (3, '4', 3)

# %%
# converting  a tuple into a list
print(type(atuple))
print(type(list(atuple)))
v = list(atuple)
print(v)
v[0] = 44244
print(v)
# Out:
# <class 'tuple'>
# <class 'list'>
# [3, '4', 3]
# [44244, '4', 3]
