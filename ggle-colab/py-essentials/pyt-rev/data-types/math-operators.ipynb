# %%
x = 7
y = 4.1
z = 0

# %whos
# Out:
# Variable   Type     Data/Info
# -----------------------------
# x          int      7
# y          float    4.1
# z          int      0

# %%
print( x - 6 )
c = x + y - 2
print(c)
# Out:
# 1
# 9.1

# %%
# flooting-point algebra vs. 'real' algebra
print( x * y)
4 / 3
# Out:
# 28.699999999999996
# 1.3333333333333333

# %%
# powers
print(3**2)
# square root
9**(1/2)
# Out:
# 9
# 3.0

# %%
FirstName = 'Jephte'
LastName = 'Pierre'
print(FirstName + ' ' + LastName)
# Out:
# Jephte Pierre

# %%
FirstName * 4
# Out:
# 'JephteJephteJephteJephte'
