# %%
# dictionary

D = dict()
D
# %whos
# Out:
# Variable   Type    Data/Info
# ----------------------------
# D          dict    n=0
# E          dict    n=2

# %%
# Key/value pair
D['name'] = 'Jephte'
D['AgeRange'] = [20, 50]

D
# Out:
# {'name': 'Jephte', 'AgeRange': [20, 50]}

# %%
E = { 'name': 'Jephte', 'AgeRange': [20, 50] }
E
# Out:
# {'name': 'Jephte', 'AgeRange': [20, 50]}

# %%
# Extract info from the dictionnary

D['name']
# Out:
# 'Jephte'

# %%
D.keys()
# Out:
# dict_keys(['name', 'AgeRange'])

# %%
# test if keys is inside dictionnary

'name' in D
# Out:
# True

# %%
'Jephte' in D # dictionnary search in keys
# Out:
# False

# %%
D.values()
# Out:
# dict_values(['Jephte', [20, 50]])

# %%
D.items()
# Out:
# dict_items([('name', 'Jephte'), ('AgeRange', [20, 50])])

# %%
# Exercise

# Input two numbers from the user
# Create a dictionary with keys 'firstNum', 'secondNum', 'product'

# %%
D = dict()

num1 = float( input('Please provide one number :' ) )
D['FirstNum'] = num1

num2 = float( input('Please provide another number :' ) )
D['secondNum'] = num2

D['product'] = num1 * num2

D.items()
# Out:
# Please provide one number :6
# Please provide another number :5
# dict_items([('FirstNum', 6.0), ('secondNum', 5.0), ('product', 30.0)])
