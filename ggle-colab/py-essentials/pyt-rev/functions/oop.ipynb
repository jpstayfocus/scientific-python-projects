# %%
# OOP (classes)

class Experiment(object):
  # constructor method
  def __init__(self, eType, dataN, status='ongoing'):
    self.exptype = eType
    self.dataCount =  dataN
    self.expStatus = status

  def increaseN(self, number):
    self.dataCount += number

  def changeExpStatus(self, status):
    self.expStatus = status

  def __str__(self):
    return 'Expermiment type: ' + self.exptype + ' has ' + str(self.dataCount) + ' data points '

# %%
myExperiment = Experiment('Brain', 120)

print(myExperiment.dataCount)

myExperiment.increaseN(10)

print(myExperiment.dataCount)

myExperiment.changeExpStatus('finished')

print(myExperiment.expStatus)
# Out:
# 120
# 130
# finished

# %%
myExperiment = Experiment('Brain', 120)
print(myExperiment)
# Out:
# Expermiment type: Brain has 120 data points
