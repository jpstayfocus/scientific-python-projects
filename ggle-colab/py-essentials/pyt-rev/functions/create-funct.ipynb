# %%
def awesomeFunction():
  print(1+1)

# %%
output = awesomeFunction()
print(output)
# Out:
# 2
# None

# %%
def superAwesomeFunction(input1, input2):
  return input1 + input2

# %%
output = superAwesomeFunction(4,8)
print(output)
# Out:
# 12

# %%
def funfun(in1,in2):
  sumres = in1+in2
  prodres = in1*in2
  print('Their sum is ' + str(sumres))
  print('Their product is ' + str(prodres))
  return sumres, prodres

# %%
outS, outP = funfun(4, 4)
print(outS)
# Out:
# Their sum is 8
# Their product is 16
# 8

# %%
# lambda fucntions

littlefun = lambda x : x**2 -1

littlefun(4)
# Out:
# 15

# %%
# Exercices
# Create a function that computes a factorial of an integer
# 5! = 5*4*3*2*1
# compare my factorial with a math module

# %%
import numpy as np

def myfactorial(val):
  return np.prod(np.arange(1, 1 + val))

# %%
import math

k=20 # result is wrong for value higher than 20
print(myfactorial(k), math.factorial(k))

# myfactorial(5)
# Out:
# 8128291617894825984 25852016738884976640000
