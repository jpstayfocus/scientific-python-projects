# %%
def funfun():
  x = 7
  y =  10
  print(x)

# %%
funfun()
# Out:
# 7

# %%
x = 3
funfun()
print(x)
print(y)
# Out:
# 7
# 3
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1149/4195178020.py in <cell line: 0>()
#       2 funfun()
#       3 print(x)
# ----> 4 print(y)
#
# NameError: name 'y' is not defined

# %%
def fz():
  print(z)

z = 3

fz()
# Out:
# 3

# %%
# Rules

# 1) variables created inside a function are local (accessible only inside the function )
# 1) variables created inside a function are global (accessible in or out of the function )

# %%
# Exercise
# write a function that flips a coin N ties and reports the average

# %%
import numpy as np

def coinflip(N):
  pCOinfClips = np.mean( np.random.randn(N)>0)
  print(str(N) + ' coin flips had ' + str(100*pCOinfClips) + '% heads')

coinflip(100000)
# Out:
# 100000 coin flips had 49.996% heads
